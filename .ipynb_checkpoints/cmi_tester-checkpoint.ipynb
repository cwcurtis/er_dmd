# %%
import knn_mi_comp as kmc
import dynamical_systems_routines as dsr
import dmd_routines as dmd
import numpy as np
import matplotlib.pyplot as plt
import scipy.linalg as sci
from copy import copy
# %matplotlib inline

# %%
def ktot_maker(kmats, lags):
    z = symbols('z')
    
    pdim, ntots = np.shape(kmats)
    ktot = Matrix(np.zeros((pdim, pdim)))
    mxlag = lags[-1]
    for cnt, lag in enumerate(lags[::-1]):
        ktot += Matrix(kmats[:, pdim*cnt:pdim*(cnt+1)]) * z**(mxlag-lag)        
    ktot -= z**mxlag*eye(pdim)
    charfun = Poly(ktot.det(), z)
    return charfun.all_coeffs()[::-1]

# %%
xbnd = 10.
dt = .01
tf = 22.
ldata = dsr.generate_lorenz63(-xbnd, xbnd, -xbnd, xbnd,-xbnd, xbnd, 100, dt, tf, seed=1973)
data_name = "Lorenz"
#ldata = dsr.generate_rossler(-xbnd, xbnd, -xbnd, xbnd,-xbnd, xbnd, 100, dt, tf, seed=1973)
#data_name = "Rossler"
#ldata = dsr.generate_vanderpol(-xbnd, xbnd, -xbnd, xbnd, 100, dt, tf, seed=1973)
# Out:
# Generating Lorenz63 system data...: 100%|█████████████████████████| 100/100 [00:05<00:00, 19.30it/s]

# %%
ldata0 = np.squeeze(ldata[0, :, :])
xvals = ldata0[0, :].reshape(-1,1)
yvals = ldata0[1, :].reshape(-1,1)
zvals = ldata0[2, :].reshape(-1,1)
i012 = kmc.cmiknn(xvals[1:], yvals[:-1], zvals[:-1], 3)

# %%
print(i012)
# Out:
# 2.5497383359169836

# %%
edist = kmc.shuffle_test(xvals[1:], yvals[:-1], zvals[:-1], 3)

# %%
ax = plt.subplot()
edist.cdf.plot(ax)

# %%
print(edist.cdf.evaluate(i012))
# Out:
# 1.0

# %%
#tstpsback = int(0./dt)
skp = int(20./dt)
nsteps = int(tf/dt) + 1
tfull = np.linspace(0,tf,nsteps)
training = np.squeeze(ldata[10, :, skp:])
tskp = tfull[skp:]
#training = tseries[:, :-tstpsback]

#pdim = training.shape[0]
#for jj in range(pdim):
#    avg = np.mean(training[jj, :])
#    sig = np.sqrt(np.mean( (training[jj, :] - avg)**2. ))
#    training[jj, :] = (training[jj, :] - avg)/sig

#test = tseries[:, -tstpsback:]
#print(np.shape(training))
#tmean = np.mean(training, 1)
#training = training - np.tile(np.mean(training, 1).reshape(-1, 1), training.shape[1])

# %%
ax = plt.axes(projection='3d')
ax.plot3D(training[0, :], training[1, :], training[2, :], 'black')

# %%
u, s, vh = np.linalg.svd(training, full_matrices=False)
print(s)
#training = u.T @ training
#treduced = training[:-1, :]
#ax = plt.axes(projection='3d')
#ax.plot3D(training[0, :], training[1, :], training[2, :], 'black')
# Out:
# [367.71057061 167.68014583  42.97487032]

# %%
plt.plot(np.fft.fftshift(np.abs(np.fft.fft(training[0,:]))))

# %%
max_lag = 100

chosen_kmats, chosen_lags = dmd.it_dmd(max_lag, training)
ed_model = dmd.lagged_model_cmp(training, chosen_kmats, chosen_lags, max_lag)

print("Final lag choices are:")
print(chosen_lags)
# Out:
# Current choices for lags are:
# [1, 15, 26, 35, 45, 48, 68, 73, 97, 99]
# Final lag choices are:
# [1, 15, 26, 35, 45, 48, 68, 73, 97, 99]

# %%
evals = dmd.evals_computer(chosen_kmats, chosen_lags)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 1
# ----> 1 evals = dmd.evals_computer(chosen_kmats, chosen_lags)
#
# File ~/Desktop/ER_DMD_Git_Clone/dmd_routines.py:44, in evals_computer(kmats, lags)
#      43 def evals_computer(kmats, lags):
# ---> 44     z = symbols('z')
#      46     pdim, ntots = np.shape(kmats)
#      47     ktot = Matrix(np.zeros((pdim, pdim)))
#
# NameError: name 'symbols' is not defined

# %%
plt.scatter(evals.real, evals.imag, s=1., c='k')
theta_vals = np.linspace(0., 2.*np.pi, 1000)
plt.plot(np.cos(theta_vals), np.sin(theta_vals),c='r')
plt.xlabel(r"$Re(\lambda)$")
plt.ylabel(r"$Im(\lambda)$")
plt.gca().set_aspect('equal')
plt.savefig(data_name+f"_spectrum_w_mx_lag_{str(chosen_lags[-1])}."+"pdf",bbox_inches='tight',format="pdf")

# %%
max_all_lag = max_lag
all_lags = list(np.arange(1, max_all_lag))

all_kmats = lagged_dmd_cmp(training, all_lags)
all_model = lagged_model_cmp(training, all_kmats, all_lags, max_all_lag)

# %%
#thorizon = chosen_lags[-1] + 190
thorizon = chosen_lags[-1] + 100

fig = plt.figure(figsize=(10, 8))
axis_labels=[r'$y_{1}$', r'$y_{2}$', r'$y_{3}$']
for dim in range(3):
    ax = fig.add_subplot(3, 1, dim+1)
    ax.plot(tskp[:thorizon], ed_model[dim, :thorizon], c='k')
    ax.plot(tskp[:thorizon], all_model[dim, :thorizon], c='r')
    ax.plot(tskp[:thorizon], training[dim, :thorizon], c='b', ls='--')
    ax.plot([tskp[chosen_lags[-1]], tskp[chosen_lags[-1]]], [np.min(ed_model[dim, :thorizon]), np.max(ed_model[dim, :thorizon])], c='k')
    ax.set_ylabel(axis_labels[dim])
    
fig.tight_layout(pad=1.0)
plt.savefig(data_name+f"_compare_w_mx_lag_{str(max_all_lag)}."+"pdf",bbox_inches='tight',format="pdf")
